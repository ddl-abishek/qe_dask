# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading csv in pandas.io.parsers.TextFileReader

# %%
data_2013_14_chunks = pd.read_csv('./Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv',
                                 chunksize=10000)

# %% [markdown]
# ## Extracting a chunk

# %%
for chunk in data_2013_14_chunks:
    df = chunk
    break

# %%
df.shape
# Out:
# (10000, 51)

# %%
df.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              46              SUBN         AUDI              P         37250
# 1              46               VAN         FORD              P         37290
# 2              46               P-U        CHEVR              P         37030
# 3              46               VAN         FORD              P         37270
# 4              41              TRLR          GMC              P         37240
#
#    ...  Hydrant Violation  Double Parking Violation  Latitude  Longitude  \
# ...

# %%
df.to_csv("./dataset_subsets/2013-14_first_10000_v1.csv")

# %% [markdown]
# ## Analyzing different fields to discern the fields to omit
# #### NOTE: len(set()) does not give a valid result on fields with NaN values and counts every instance of NaN as a new value

# %%
for field_name in df:
    print(field_name," ; ",len(set(df[field_name]))," unique values")
    print(df[field_name].value_counts())
    print("-----------------------------")
# Out:
# Summons Number  ;  10000  unique values
# 1348782079    1
# 1311698255    1
# 1325195698    1
# 1347923287    1
# 1333716310    1
#              ..
# 1340660374    1
# 1345782421    1
# 1341868692    1
# 1314271891    1
# 1334738944    1
# Name: Summons Number, Length: 10000, dtype: int64
# -----------------------------
# Plate ID  ;  8722  unique values
# 44884      48
# 355969     15
# 4JS3927    14
# 41768JM    13
# 4EJ3315    13
#            ..
# 55938MC     1
# GDL6917     1
# FDN1462     1
# GBJ3972     1
# 78786JX     1
# Name: Plate ID, Length: 8721, dtype: int64
# -----------------------------
# Registration State  ;  53  unique values
# NY    6460
# NJ     923
# PA     607
# 99     251
# CT     194
# VA     184
# FL     181
# IL     139
# TN     125
# MA     121
# CA      98
# RI      90
# MD      75
# NC      71
# GA      60
# OK      60
# SC      56
# IN      53
# OR      39
# ME      26
# TX      25
# MI      15
# MN      13
# DE      12
# WI      12
# MS      11
# ...

# %% [markdown]
# ## Extracting second chunk for comaparison of certain fields

# %%
chunk_no = 1
for chunk in data_2013_14_chunks:
    if chunk_no == 2:
        df_2 = chunk
        break
    else:
        chunk_no +=1

# %%
df_2['Issuer Squad'].value_counts()
# Out:
# 0    10000
# Name: Issuer Squad, dtype: int64

# %%
df_2['Violation Post Code'].value_counts()
# Out:
# Series([], Name: Violation Post Code, dtype: int64)

# %% [markdown]
# ## Extracting third, fourth and fifth chunk for comaparison of certain fields

# %%
chunk_no = 1
for chunk in data_2013_14_chunks:
    if chunk_no == 3:
        df_3 = chunk
    elif chunk_no == 4:
        df_4 = chunk
    elif chunk_no == 5:
        df_5 = chunk
        break
    else:
        chunk_no +=1

# %%
print(df_3['Issuer Squad'].value_counts())
# print(df_4['Issuer Squad'].value_counts())
# print(df_5['Issuer Squad'].value_counts())
# Out:
# Q    89
# E    88
# D    50
# A    17
# R    14
# K    13
# C     7
# Name: Issuer Squad, dtype: int64

# %%
print(df_3['Violation Post Code'].value_counts())
# Out:
# 04 6    37
# C 77    33
# MC 9    30
# 28 7    23
# 08 3    21
# 06 4    20
# 99 6    17
# 57-A    17
# 42 7    17
# 26 7    16
# 28 4    14
# 16 6    14
# 57 7     7
# 10 3     7
# 28 6     5
# Name: Violation Post Code, dtype: int64

# %%
df['Violation Description'].value_counts()
# Out:
# Series([], Name: Violation Description, dtype: int64)

# %%
df_2['Violation Description'].value_counts()
# Out:
# Series([], Name: Violation Description, dtype: int64)

# %%
violation_desc = set()
violation_list = ['dui','dui','jumped red light','drove on sidewalk','dui']
violation_list1 = ['homicide','drove on sidewalk','di','jumped redlight']

violation_desc.add(violation_list)
violation_desc.add(violation_list1)

print(violation_desc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-d08ae86aabdf> in <module>
#       3 violation_list1 = ['homicide','drove on sidewalk','di','jumped redlight']
#       4
# ----> 5 violation_desc.add(violation_list)
#       6 violation_desc.add(violation_list1)
#       7
#
# TypeError: unhashable type: 'list'
