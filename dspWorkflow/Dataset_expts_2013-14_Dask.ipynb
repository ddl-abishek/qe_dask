# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading dataframe through Dask

# %%
# %%time
df = dd.read_csv('./Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv')
# Out:
# CPU times: user 374 ms, sys: 5.59 ms, total: 380 ms
# Wall time: 414 ms

# %%
df.head()
# Out:
# /home/abishek/miniconda3/envs/anishka/lib/python3.8/site-packages/dask/core.py:121: DtypeWarning: Columns (18,29,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# ~/miniconda3/envs/anishka/lib/python3.8/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~/miniconda3/envs/anishka/lib/python3.8/site-packages/dask/dataframe/core.py in _head(self, n, npartitions, compute, safe)
#    1036
# ...
