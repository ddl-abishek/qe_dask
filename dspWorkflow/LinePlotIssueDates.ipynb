# %% [markdown]
# # When are tickets most likely to be issued? Any seasonality?

# %%
import pandas as pd
import dask as dd
import seaborn as sns
from datetime import datetime
from collections import defaultdict
from matplotlib import pyplot

# %%
class IssueDateLinePlot:
    def __init__(self,path):
        dateparse = lambda x: datetime.strptime(x, '%m/%d/%Y')
        
        data = pd.read_csv(path,
                           usecols=[ 'Issue Date'],
                           parse_dates=['Issue Date'],
                           date_parser=dateparse)
        
        print("data.shape : ",data.shape)
        
        months = defaultdict(int)
        
        for date in data['Issue Date']:
            months[date.month] += 1
            
        months_ordered = {'Jan':0,'Feb':0,'Mar':0,
                          'Apr':0,'May':0,'Jun':0,
                          'July':0,'Aug':0,'Sept':0,
                          'Oct':0,'Nov':0,'Dec':0}
        
        for i,key in enumerate(months_ordered.keys()):
            months_ordered[key] = months[i+1]
        breakpoint()
        self.months_df = pd.DataFrame(months_ordered.items(),columns=['Month','Issue Date'])
        

        
    def plot(self):
        _, ax = pyplot.subplots(figsize=(12,9))
        sns.set(style="darkgrid")
        
        # Plot the isse dates for different months
        sns.lineplot(x="Month",y="Issue Date",ax=ax,data=self.months_df,sort=False)

# %%
obj_13_14 = IssueDateLinePlot("/mnt/data/dspWorkflow_dask_testcase/nyc-parking-tickets_csvs/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv")
obj_13_14.plot()
# Out:
# data.shape :  (9100278, 1)
# > <ipython-input-3-0ba2c9eceffe>(25)__init__()
#      23             months_ordered[key] = months[i+1]
#      24         breakpoint()
# ---> 25         self.months_df = pd.DataFrame(months_ordered.items(),columns=['Month','Issue Date'])
#      26
#      27
# ipdb>  months
# defaultdict(<class 'int'>, {8: 838950, 7: 173157, 3: 907505, 6: 681133, 5: 898409, 9: 827402, 4: 860217, 10: 953458, 1: 722439, 2: 654201, 12: 734760, 11: 848647})
# ipdb>  data.shape
# (9100278, 1)
# ipdb>  sum(months.keys()) == data.shape[0]
# False
# ipdb>  sum(months.keys())
# 78
# ipdb>  sum(months.values()) == data.shape[0]
# True
# ipdb>  n
# --Return--
# None
# > <ipython-input-3-0ba2c9eceffe>(25)__init__()
#      23             months_ordered[key] = months[i+1]
#      24         breakpoint()
# ---> 25         self.months_df = pd.DataFrame(months_ordered.items(),columns=['Month','Issue Date'])
#      26
#      27
# ipdb>  n
# --Return--
# None
# ...

# %%
obj_15 = IssueDateLinePlot("./Parking_Violations_Issued_-_Fiscal_Year_2015.csv")
obj_15.plot()
# Out:
# data.shape :  (11809233, 1)

# %%
obj_16 = IssueDateLinePlot("./Parking_Violations_Issued_-_Fiscal_Year_2016.csv")
obj_16.plot()
# Out:
# data.shape :  (10626899, 1)

# %%
obj_17 = IssueDateLinePlot("./Parking_Violations_Issued_-_Fiscal_Year_2017.csv")
obj_17.plot()
# Out:
# data.shape :  (10803028, 1)
